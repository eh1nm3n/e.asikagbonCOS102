# %% [markdown]
# # Simple Interest
# ![Simple Interest](simpleinterest.png)

# %%
# Simple Interest 
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest (%): "))
time = float(input("Enter the time in years: "))

simple_interest = (principal * rate * time) / 100

print("Simple Interest =", simple_interest)
# Out:
# Enter the principal amount:  100
# Enter the rate of interest (%):  3
# Enter the time in years:  7
# Simple Interest = 21.0

# %% [markdown]
# # Compound Interest
# ![Compound Interest](compoundinterest.png)

# %%
# Compound Interest 
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the annual interest rate (%): "))
time = float(input("Enter the time in years: "))

amount = principal * (1 + rate/100) ** time
compound_interest = amount - principal

print("Compound Interest =", compound_interest)
print("Total Amount =", amount)
# Out:
# Enter the principal amount:  300
# Enter the annual interest rate (%):  10
# Enter the time in years:  8
# Compound Interest = 343.07664300000044
# Total Amount = 643.0766430000004

# %% [markdown]
# # Annuity Interest
# ![Annuity Interest](annuityinterest.png)

# %%
# Annual Plan 
payment = float(input("Enter the payment per period: "))
rate = float(input("Enter the interest rate (%): "))
periods = int(input("Enter the number of periods: "))

r = rate / 100

future_value = payment * ((1 + r) ** periods - 1) / r

print("Future Value of the Annuity =", future_value)
# Out:
# Enter the payment per period:  100
# Enter the interest rate (%):  2
# Enter the number of periods:  399
# Future Value of the Annuity = 13498257.121831354
