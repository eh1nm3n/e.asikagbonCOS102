# %% [markdown]
# ![Screenshot 2026-03-11 152359.png](attachment:8264b7d4-1c12-4ab2-8d76-92bbba8c5d9f.png)
# ![Screenshot 2026-03-11 131028.png](attachment:36461643-3e0b-4095-946f-1c3b9c7407f0.png)
# ![Screenshot 2026-03-11 131105.png](attachment:de15cfd5-d70e-4210-88a5-b0eb557e7a69.png)
