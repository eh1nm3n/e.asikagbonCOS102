# %% [markdown]
# ![Screenshot 2026-03-11 152359.png](attachment:e9affe89-8a2a-42df-b8d9-7f81c2a1d320.png)

# %% [markdown]
# ![Screenshot 2026-03-11 131105.png](attachment:cbd60b9c-2b86-4ddf-a705-ca936db2496a.png)

# %% [markdown]
# ![Screenshot 2026-03-11 131028.png](attachment:0dc8cf51-8902-4ce7-a38b-45aa8bb9d524.png)
